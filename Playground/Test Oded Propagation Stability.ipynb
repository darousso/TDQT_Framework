# %%
import dealwithpath
from TDQT import *

# %%
structure_config="Oded"
V_bias=0.3 #V
T_L=0 #K
T_R=0 #K
T_EM=0 #K

H, S, size_lead_L,size_lead_R = Get_Structure(structure_config)
device = Device(
    H=H, 
    S=S, 
    size_lead_L=size_lead_L,size_lead_R=size_lead_R,
    V_bias=V_bias,
    T_L=T_L, T_R=T_R, T_EM=T_EM,
    clean_matrices=True
)
# device.Visualize()
# Out:
# /eos/home-i00/d/drousso/SWAN_projects/TDQT_NEW/Examples/../TDQT/device_defn.py:112: RuntimeWarning: divide by zero encountered in divide
#   Target_P0ss[:size_lead_L,:size_lead_L]=np.diag(expit(- (E_L - mu_L) / (kB * T_L)))
# /eos/home-i00/d/drousso/SWAN_projects/TDQT_NEW/Examples/../TDQT/device_defn.py:113: RuntimeWarning: divide by zero encountered in divide
#   Target_P0ss[-size_lead_R:,-size_lead_R:]=np.diag(expit(- (E_R - mu_R) / (kB * T_R)))
# /eos/home-i00/d/drousso/SWAN_projects/TDQT_NEW/Examples/../TDQT/device_defn.py:114: RuntimeWarning: divide by zero encountered in divide
#   Target_P0ss[size_lead_L:size_lead_L+size_EM,size_lead_L:size_lead_L+size_EM]=np.diag(expit(- (E_EM - mu_EM) / (kB * T_EM)))

# %% [markdown]
# # Site Representation

# %%
# Gamma     = 0 *invfs
# Delta_t   = 1 *fs
# max_iters = 100
# list_of_outputs=["P@S diagonal","J All Elements","J Leads Only"]
# solver_type="Forwards Difference"

# solver = Solver(device,
#     Gamma=Gamma, 
#     Delta_t=Delta_t, 
#     max_iters=max_iters, 
#     list_of_outputs=list_of_outputs, 
# )
# outputs_dict=solver.Propagate_In_Site(solver_type=solver_type)
# t_vec_in_fs=solver.t_vec_in_fs
# plots_dict=solver.Visualize_Results(figsize=(5,5),dpi=200)

# %%
# Gamma     = 0.001 *invfs
# Delta_t   = 1 *fs
# max_iters = 100
# list_of_outputs=["P@S diagonal","J All Elements","J Leads Only"]
# solver_type="Central Difference"

# solver = Solver(device,
#     Gamma=Gamma, 
#     Delta_t=Delta_t, 
#     max_iters=max_iters, 
#     list_of_outputs=list_of_outputs, 
# )
# outputs_dict=solver.Propagate_In_Site(solver_type=solver_type)
# t_vec_in_fs=solver.t_vec_in_fs
# plots_dict=solver.Visualize_Results(figsize=(5,5),dpi=200)

# %%
# Gamma     = 0.001 *invfs
# Delta_t   = 1 *fs
# max_iters = 100
# list_of_outputs=["P@S diagonal","J All Elements","J Leads Only"]
# solver_type="Crank-Nicholson"

# solver = Solver(device,
#     Gamma=Gamma, 
#     Delta_t=Delta_t, 
#     max_iters=max_iters, 
#     list_of_outputs=list_of_outputs, 
# )
# outputs_dict=solver.Propagate_In_Site(solver_type=solver_type)
# t_vec_in_fs=solver.t_vec_in_fs
# plots_dict=solver.Visualize_Results(figsize=(5,5),dpi=200)

# %%
# Gamma     = 0.010 *invfs
# Delta_t   = 1 *fs
# max_iters = 100
# list_of_outputs=["P@S diagonal","J All Elements","J Leads Only"]

# solver = Solver(device,
#     Gamma=Gamma, 
#     Delta_t=Delta_t, 
#     max_iters=max_iters, 
#     list_of_outputs=list_of_outputs, 
# )
# outputs_dict=solver.Propagate_In_Site_SciPy()
# t_vec_in_fs=solver.t_vec_in_fs
# plots_dict=solver.Visualize_Results(figsize=(5,5),dpi=200)

# %%
Gamma     = 0.010 *invfs
Delta_t   = 1 *fs
max_iters = 100
list_of_outputs=["P@S diagonal","J All Elements","J Leads Only"]
solver_type="RK45"

solver = Solver(device,
    Gamma=Gamma, 
    Delta_t=Delta_t, 
    max_iters=max_iters, 
    list_of_outputs=list_of_outputs, 
)
outputs_dict=solver.Propagate_In_Site(solver_type=solver_type)
t_vec_in_fs=solver.t_vec_in_fs
plots_dict=solver.Visualize_Results(figsize=(5,5),dpi=200)
# Out:
# Step 3: Convergence failed, restoring P from the previous time step.
# Step 4: Convergence failed, restoring P from the previous time step.
# Step 5: Convergence failed, restoring P from the previous time step.
# Step 6: Convergence failed, restoring P from the previous time step.
# Step 7: Convergence failed, restoring P from the previous time step.
# Step 8: Convergence failed, restoring P from the previous time step.
# Step 9: Convergence failed, restoring P from the previous time step.
# Step 10: Convergence failed, restoring P from the previous time step.
# Step 10 out of 100 - Time: 355.90s
# Delta_t, current_t [fs]= 0.8871749279627806 2.558688627657587
# Step 11: Convergence failed, restoring P from the previous time step.
# Step 12: Convergence failed, restoring P from the previous time step.
# Step 13: Convergence failed, restoring P from the previous time step.
# Step 14: Convergence failed, restoring P from the previous time step.
# Step 15: Convergence failed, restoring P from the previous time step.
# Step 16: Convergence failed, restoring P from the previous time step.
# Step 17: Convergence failed, restoring P from the previous time step.
# Step 18: Convergence failed, restoring P from the previous time step.
# Step 19: Convergence failed, restoring P from the previous time step.
# Step 20: Convergence failed, restoring P from the previous time step.
# Step 20 out of 100 - Time: 774.40s
# Delta_t, current_t [fs]= 0.8871714043902712 2.558688627657587
# Step 21: Convergence failed, restoring P from the previous time step.
# Step 22: Convergence failed, restoring P from the previous time step.
# Step 23: Convergence failed, restoring P from the previous time step.
# Step 24: Convergence failed, restoring P from the previous time step.
# Step 25: Convergence failed, restoring P from the previous time step.
# Step 26: Convergence failed, restoring P from the previous time step.
# Step 27: Convergence failed, restoring P from the previous time step.
# Step 29: Convergence failed, restoring P from the previous time step.
# Step 30: Convergence failed, restoring P from the previous time step.
# Step 30 out of 100 - Time: 1133.12s
# Delta_t, current_t [fs]= 0.8059336990795146 3.4458600320474644
# Step 32: Convergence failed, restoring P from the previous time step.
# Step 34: Convergence failed, restoring P from the previous time step.
# Step 36: Convergence failed, restoring P from the previous time step.
# Step 38: Convergence failed, restoring P from the previous time step.
# Step 40: Convergence failed, restoring P from the previous time step.
# Step 40 out of 100 - Time: 1527.51s
# Delta_t, current_t [fs]= 0.6998373425072545 7.229949095940151
# Step 42: Convergence failed, restoring P from the previous time step.
# Step 44: Convergence failed, restoring P from the previous time step.
# Step 45: Convergence failed, restoring P from the previous time step.
# Step 46: Convergence failed, restoring P from the previous time step.
# Step 47: Convergence failed, restoring P from the previous time step.
# Step 48: Convergence failed, restoring P from the previous time step.
# Step 49: Convergence failed, restoring P from the previous time step.
# Step 50: Convergence failed, restoring P from the previous time step.
# Step 50 out of 100 - Time: 1899.81s
# Delta_t, current_t [fs]= 0.669863636884275 8.630918301059053
# Step 51: Convergence failed, restoring P from the previous time step.
# Step 52: Convergence failed, restoring P from the previous time step.
# Step 53: Convergence failed, restoring P from the previous time step.
# Step 54: Convergence failed, restoring P from the previous time step.
# Step 58: Convergence failed, restoring P from the previous time step.
# Step 59: Convergence failed, restoring P from the previous time step.
# Step 60: Convergence failed, restoring P from the previous time step.
# Step 60 out of 100 - Time: 2257.41s
# Delta_t, current_t [fs]= 0.6698636353023709 8.630918301059053
# Step 61: Convergence failed, restoring P from the previous time step.
# Step 63: Convergence failed, restoring P from the previous time step.
# Step 64: Convergence failed, restoring P from the previous time step.
# Step 65: Convergence failed, restoring P from the previous time step.
# Step 66: Convergence failed, restoring P from the previous time step.
# Step 67: Convergence failed, restoring P from the previous time step.
# Step 68: Convergence failed, restoring P from the previous time step.
# Step 69: Convergence failed, restoring P from the previous time step.
# Step 70: Convergence failed, restoring P from the previous time step.
# Step 70 out of 100 - Time: 2627.02s
# Delta_t, current_t [fs]= 0.29394772984923856 9.300781936361423
# Step 71: Convergence failed, restoring P from the previous time step.
# Step 72: Convergence failed, restoring P from the previous time step.
# Step 73: Convergence failed, restoring P from the previous time step.
# Step 74: Convergence failed, restoring P from the previous time step.
# Step 75: Convergence failed, restoring P from the previous time step.
# Step 76: Convergence failed, restoring P from the previous time step.
# Step 77: Convergence failed, restoring P from the previous time step.
# Step 78: Convergence failed, restoring P from the previous time step.
# Step 79: Convergence failed, restoring P from the previous time step.
# Step 80: Convergence failed, restoring P from the previous time step.
# Step 80 out of 100 - Time: 2972.10s
# Delta_t, current_t [fs]= 0.002067906773959734 9.300781936361423
# Step 81: Convergence failed, restoring P from the previous time step.
# Step 82: Convergence failed, restoring P from the previous time step.
# Step 83: Convergence failed, restoring P from the previous time step.
# Step 84: Convergence failed, restoring P from the previous time step.
# Step 85: Convergence failed, restoring P from the previous time step.
# Step 86: Convergence failed, restoring P from the previous time step.
# Step 87: Convergence failed, restoring P from the previous time step.
# Step 88: Convergence failed, restoring P from the previous time step.
# Step 89: Convergence failed, restoring P from the previous time step.
# Step 90: Convergence failed, restoring P from the previous time step.
# Step 90 out of 100 - Time: 3334.11s
# Delta_t, current_t [fs]= 1.0036383647773069e-05 9.300781936361423
# Step 91: Convergence failed, restoring P from the previous time step.
# Step 92: Convergence failed, restoring P from the previous time step.
# Step 93: Convergence failed, restoring P from the previous time step.
# Step 94: Convergence failed, restoring P from the previous time step.
# Step 95: Convergence failed, restoring P from the previous time step.
# Step 96: Convergence failed, restoring P from the previous time step.
# Step 97: Convergence failed, restoring P from the previous time step.
# Step 98: Convergence failed, restoring P from the previous time step.
# Step 99: Convergence failed, restoring P from the previous time step.
# /cvmfs/sft.cern.ch/lcg/views/LCG_106a_swan/x86_64-el9-gcc13-opt/lib/python3.11/site-packages/matplotlib/cbook.py:1699: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /cvmfs/sft.cern.ch/lcg/views/LCG_106a_swan/x86_64-el9-gcc13-opt/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
# Gamma     = 1.000 *invfs
# Delta_t   = 1 *fs
# max_iters = 100
# list_of_outputs=["P@S diagonal","J All Elements","J Leads Only"]
# solver_type="SciPy_Adaptive"

# solver = Solver(device,
#     Gamma=Gamma, 
#     Delta_t=Delta_t, 
#     max_iters=max_iters, 
#     list_of_outputs=list_of_outputs, 
# )
# outputs_dict=solver.Propagate_In_Site(solver_type=solver_type)
# t_vec_in_fs=solver.t_vec_in_fs
# plots_dict=solver.Visualize_Results(figsize=(5,5),dpi=200)

# %% [markdown]
# # State Representation

# %%
# Gamma     = 0 *invfs
# Delta_t   = 1 *fs
# max_iters = 100
# max_t = 3000*fs
# list_of_outputs=["Pss diagonal","J Leads Only From State","P@S diagonal From State"]
# solver_type="Forwards Difference"

# solver = Solver(device,
#     Gamma=Gamma, 
#     Delta_t=Delta_t, 
#     max_iters=max_iters, 
#     list_of_outputs=list_of_outputs, 
# )
# outputs_dict=solver.Propagate_In_State(solver_type=solver_type)
# t_vec_in_fs=solver.t_vec_in_fs
# plots_dict=solver.Visualize_Results(figsize=(5,5),dpi=200)

# %%
# Gamma     = 0.001 *invfs
# Delta_t   = 1 *fs
# max_iters = 100
# list_of_outputs=["Pss diagonal","J Leads Only From State","P@S diagonal From State"]
# solver_type="Forwards Difference"

# solver = Solver(device,
#     Gamma=Gamma, 
#     Delta_t=Delta_t, 
#     max_iters=max_iters, 
#     list_of_outputs=list_of_outputs, 
# )
# outputs_dict=solver.Propagate_In_State(solver_type=solver_type)
# t_vec_in_fs=solver.t_vec_in_fs
# plots_dict=solver.Visualize_Results(figsize=(5,5),dpi=200)

# %%
# Gamma     = 0.001 *invfs
# Delta_t   = 1 *fs
# max_iters = 100
# list_of_outputs=["Pss diagonal","J Leads Only From State","P@S diagonal From State"]
# solver_type="Crank-Nicholson"

# solver = Solver(device,
#     Gamma=Gamma, 
#     Delta_t=Delta_t, 
#     max_iters=max_iters, 
#     list_of_outputs=list_of_outputs, 
# )
# outputs_dict=solver.Propagate_In_State(solver_type=solver_type)
# t_vec_in_fs=solver.t_vec_in_fs
# plots_dict=solver.Visualize_Results(figsize=(5,5),dpi=200)

# %%
# Gamma     = 0.010 *invfs
# Delta_t   = 1 *fs
# max_iters = 100
# list_of_outputs=["Pss diagonal","J Leads Only From State","P@S diagonal From State"]
# solver_type="RK4"

# solver = Solver(device,
#     Gamma=Gamma, 
#     Delta_t=Delta_t, 
#     max_iters=max_iters, 
#     list_of_outputs=list_of_outputs, 
# )
# outputs_dict=solver.Propagate_In_State(solver_type=solver_type)
# t_vec_in_fs=solver.t_vec_in_fs
# plots_dict=solver.Visualize_Results(figsize=(5,5),dpi=200)

# %%
# Gamma     = 0.010 *invfs
# Delta_t   = 1 *fs
# max_iters = 100
# list_of_outputs=["Pss diagonal","J Leads Only From State","P@S diagonal From State"]
# solver_type="Implicit Euler"

# solver = Solver(device,
#     Gamma=Gamma, 
#     Delta_t=Delta_t, 
#     max_iters=max_iters, 
#     list_of_outputs=list_of_outputs, 
# )
# outputs_dict=solver.Propagate_In_State(solver_type=solver_type)
# t_vec_in_fs=solver.t_vec_in_fs
# plots_dict=solver.Visualize_Results(figsize=(5,5),dpi=200)

# %%
# Gamma     = 0.000 *invfs
# Delta_t   = 1 *fs
# max_iters = 100
# list_of_outputs=["Pss diagonal","J Leads Only From State","P@S diagonal From State"]
# solver_type="Implicit Euler"

# solver = Solver(device,
#     Gamma=Gamma, 
#     Delta_t=Delta_t, 
#     max_iters=max_iters, 
#     list_of_outputs=list_of_outputs, 
# )
# outputs_dict=solver.Propagate_In_State(solver_type=solver_type)
# t_vec_in_fs=solver.t_vec_in_fs
# plots_dict=solver.Visualize_Results(figsize=(5,5),dpi=200)

# %%
# Gamma     = 0.010 *invfs
# Delta_t   = 1 *fs
# max_iters = 100
# list_of_outputs=["P@S diagonal","J All Elements","J Leads Only"]

# solver = Solver(device,
#     Gamma=Gamma, 
#     Delta_t=Delta_t, 
#     max_iters=max_iters, 
#     list_of_outputs=list_of_outputs, 
# )
# outputs_dict=solver.Propagate_In_State_SciPy()
# t_vec_in_fs=solver.t_vec_in_fs
# plots_dict=solver.Visualize_Results(figsize=(5,5),dpi=200)

# %%
Gamma     = 0.010 *invfs
Delta_t   = 1 *fs
max_iters = 100
list_of_outputs=["P@S diagonal","J All Elements","J Leads Only"]
solver_type="RK4_Adaptive_Step"

solver = Solver(device,
    Gamma=Gamma, 
    Delta_t=Delta_t, 
    max_iters=max_iters, 
    list_of_outputs=list_of_outputs, 
)
outputs_dict=solver.Propagate_In_State(solver_type=solver_type)
t_vec_in_fs=solver.t_vec_in_fs
plots_dict=solver.Visualize_Results(figsize=(5,5),dpi=200)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_898/2900169190.py in <module>
#      11     list_of_outputs=list_of_outputs,
#      12 )
# ---> 13 outputs_dict=solver.Propagate_In_State(solver_type=solver_type)
#      14 t_vec_in_fs=solver.t_vec_in_fs
#      15 plots_dict=solver.Visualize_Results(figsize=(5,5),dpi=200)
#
# /eos/home-i00/d/drousso/SWAN_projects/TDQT_NEW/Examples/../TDQT/solvers.py in Propagate_In_State(self, solver_type)
#     307         Delta_t_scaled = self.Delta_t_scaled
#     308         NBas = Pss.size  # Total number of basis functions (dimension of the matrices)
# --> 309         outputs_dict = {output_type: [self.output_funcs_state_dict[output_type](Pss)] for output_type in self.list_of_outputs}
#     310         t_vec_scaled = [0]
#     311
#
# /eos/home-i00/d/drousso/SWAN_projects/TDQT_NEW/Examples/../TDQT/solvers.py in <dictcomp>(.0)
#     307         Delta_t_scaled = self.Delta_t_scaled
#     308         NBas = Pss.size  # Total number of basis functions (dimension of the matrices)
# --> 309         outputs_dict = {output_type: [self.output_funcs_state_dict[output_type](Pss)] for output_type in self.list_of_outputs}
#     310         t_vec_scaled = [0]
#     311
#
# KeyError: 'P@S diagonal'

# %% [markdown]
# # Manually checking

# %%
solver.Initial_P0ss
